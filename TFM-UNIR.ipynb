# %%
#TFM-UNIR

#General imports

import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
#Calculate Angels

def calculate_angle(a,b,c):
    a = np.array(a) #First
    b = np.array(b) #Mid
    c = np.array(c) #End

    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b [0])
    angle = np.abs(radians*180.0/np.pi)

    if angle > 180.0:
        angle = 360 - angle
        
    return angle

# %%
# #Extract angles

# cap = cv2.VideoCapture(0)

# # Setup mediapipe instance
# with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#     while cap.isOpened():
#         ret, frame = cap.read()

#         # Detect stuff and render
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#         # Make detection
#         image.flags.writeable = False
#         results = pose.process(image)

#         # Extract landmarks
#         try:
#             landmarks = results.pose_landmarks.landmark

#             shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#             elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
#             wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

#             angle = calculate_angle(shoulder,elbow,wrist)

#             #Visualize angle
#             cv2.putText(image,str(angle),
#                         tuple(np.multiply(elbow, [640, 480]).astype(int)),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA)


#             # print(landmarks)
#         except:
#             pass

#         # Render
#         image.flags.writeable = True
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
#                                   mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
#                                   mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

#         cv2.imshow('Video', image)

#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break

#     cap.release()
#     cv2.destroyAllWindows()

# %%
# #Propuesta openAI

# #TFM-UNIR

# #General imports

# import cv2
# import mediapipe as mp
# import numpy as np
# mp_drawing = mp.solutions.drawing_utils
# mp_pose = mp.solutions.pose

# #Calculate Angels

# def calculate_angle(a,b,c):
#     a = np.array(a) #First
#     b = np.array(b) #Mid
#     c = np.array(c) #End

#     radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b [0])
#     angle = np.abs(radians*180.0/np.pi)

#     if angle > 180.0:
#         angle = 360 - angle
        
#     return angle

# #Extract angles

# cap = cv2.VideoCapture(0)

# # Setup mediapipe instance
# with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    
#     # Menu interactivo
#     while True:
#         print("Seleccione el brazo para calcular el ángulo: ")
#         print("1. Brazo izquierdo")
#         print("2. Brazo derecho")
#         print("3. Hombro izquierdo")
#         print("4. Hombro derecho")
#         selection = input("Ingrese su selección: ")

#         if selection == "1":
#             joint1 = mp_pose.PoseLandmark.LEFT_SHOULDER.value
#             joint2 = mp_pose.PoseLandmark.LEFT_ELBOW.value
#             joint3 = mp_pose.PoseLandmark.LEFT_WRIST.value
#             break
#         elif selection == "2":
#             joint1 = mp_pose.PoseLandmark.RIGHT_SHOULDER.value
#             joint2 = mp_pose.PoseLandmark.RIGHT_ELBOW.value
#             joint3 = mp_pose.PoseLandmark.RIGHT_WRIST.value
#             break
#         elif selection == "3":
#             joint1 = mp_pose.PoseLandmark.LEFT_HIP.value
#             joint2 = mp_pose.PoseLandmark.LEFT_SHOULDER.value
#             joint3 = mp_pose.PoseLandmark.LEFT_ELBOW.value
#             break
#         elif selection == "4":
#             joint1 = mp_pose.PoseLandmark.RIGHT_HIP.value
#             joint2 = mp_pose.PoseLandmark.RIGHT_SHOULDER.value
#             joint3 = mp_pose.PoseLandmark.RIGHT_ELBOW.value
#             break
#         else:
#             print("Selección inválida. Inténtelo de nuevo.")

#     while cap.isOpened():
#         ret, frame = cap.read()

#         # Detect stuff and render
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#         # Make detection
#         image.flags.writeable = False
#         results = pose.process(image)

#         # Extract landmarks
#         try:
#             landmarks = results.pose_landmarks.landmark

#             shoulder = [landmarks[joint1].x,landmarks[joint1].y]
#             elbow = [landmarks[joint2].x,landmarks[joint2].y]
#             wrist = [landmarks[joint3].x,landmarks[joint3].y]

#             angle = calculate_angle(shoulder,elbow,wrist)

#             #Visualize angle
#             cv2.putText(image,str(angle),
#                         tuple(np.multiply(elbow, [640, 480]).astype(int)),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA)


#             # print(landmarks)
#         except:
#             pass

#         # Render
#         image.flags.writeable = True
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
#                                   mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
#                                   mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2),
#                                   landmark_drawing_spec=mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
#                                   connection_drawing_spec=mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=2, circle_radius=2),
#                                   upper_body_only=True,
#                                   )


#         cv2.imshow('Video', image)

#         if cv2.waitKey(50) & 0xFF == ord('q'):
#             break

#     cap.release()
#     cv2.destroyAllWindows()

# %%
#Código con una única extremidad. Menú contar reps añadido

#Propuesta openAI

#TFM-UNIR

#General imports

import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

#Calculate Angels

def calculate_angle(a,b,c):
    a = np.array(a) #First
    b = np.array(b) #Mid
    c = np.array(c) #End

    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b [0])
    angle = np.abs(radians*180.0/np.pi)

    if angle > 180.0:
        angle = 360 - angle
        
    return angle

#Extract angles

cap = cv2.VideoCapture(0)

# Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:

    while True:
        # Interactive menu
        print("¿Qué acción desea realizar?")
        print("1. Calcular el ángulo de una extremidad.")
        print("2. Contar repeticiones con una extremidad.")
        selection = input("Ingrese su selección: ")

        show_joint_menu = False

        if selection == "1":
            show_joint_menu = True

        elif selection == "2":
            rep_count = 0
            rep_started = False
            show_joint_menu = True

        else:
            print("Selección inválida. Inténtelo de nuevo.")
        
    
        if show_joint_menu:
            print("¿Qué articulación desea seleccionar?")
            print("1. hombro izquierdo.")
            selection_art = input("Ingrese su selección: ")

            if selection_art == "1":
                joint1 = mp_pose.PoseLandmark.LEFT_HIP.value
                joint2 = mp_pose.PoseLandmark.LEFT_SHOULDER.value
                joint3 = mp_pose.PoseLandmark.LEFT_ELBOW.value
                break

            else:
                print("Selección inválida. Inténtelo de nuevo.")


    while cap.isOpened():
        ret, frame = cap.read()

        # Detect stuff and render
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Make detection
        image.flags.writeable = False
        results = pose.process(image)

        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark

            shoulder = [landmarks[joint1].x,landmarks[joint1].y]
            elbow = [landmarks[joint2].x,landmarks[joint2].y]
            wrist = [landmarks[joint3].x,landmarks[joint3].y]

            angle = calculate_angle(shoulder,elbow,wrist)

            #Visualize angle
            cv2.putText(image,str(angle),
                        tuple(np.multiply(elbow, [640, 480]).astype(int)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA)


            # Count reps if option 2 is selected
            if selection == "2":
                if angle > 160 and not rep_started:
                    rep_started = True

                elif angle < 80 and rep_started:
                    rep_count += 1
                    rep_started = False

                cv2.putText(image,"Reps: " + str(rep_count),
                        (10, 50),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2, cv2.LINE_AA)

        except:
            pass

        # Render
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        cv2.imshow('Video', image)

        if cv2.waitKey(50) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ¿Qué acción desea realizar?
# 1. Calcular el ángulo de una extremidad.
# 2. Contar repeticiones con una extremidad.
# ¿Qué articulación desea seleccionar?
# 1. hombro izquierdo.
